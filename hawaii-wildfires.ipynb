# %%
import pandas as pd
import os

# %%
dfi = pd.read_csv('https://data.cyverse.org/dav-anon/iplant/home/lisestdenis/ics209-plus-wf_incidents_1999to2020.csv', low_memory=False)
dfs = pd.read_csv('https://data.cyverse.org/dav-anon/iplant/home/lisestdenis/ics209-plus-wf_sitreps_1999to2018.csv', low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 dfi = pd.read_csv('https://data.cyverse.org/dav-anon/iplant/home/lisestdenis/ics209-plus-wf_incidents_1999to2020.csv', low_memory=False)
# ----> 2 dfs = pd.read_csv('https://data.cyverse.org/dav-anon/iplant/home/lisestdenis/ics209-plus-wf_sitreps_1999to2018.csv', low_memory=False)
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'INCIDENT_ID', 'INCIDENT_NUMBER', 'INCIDENT_NAME',
#        'INCTYP_ABBREVIATION', 'FINAL_ACRES', 'CAUSE', 'COMPLEX',
#        'DISCOVERY_DATE', 'DISCOVERY_DOY', 'EXPECTED_CONTAINMENT_DATE',
#        'FATALITIES', 'FUEL_MODEL', 'INCIDENT_DESCRIPTION', 'INC_IDENTIFIER',
#        'INJURIES_TOTAL', 'LL_CONFIDENCE', 'LL_UPDATE', 'LOCAL_TIMEZONE',
#        'POO_CITY', 'POO_COUNTY', 'POO_LATITUDE', 'POO_LONGITUDE',
#        'POO_SHORT_LOCATION_DESC', 'POO_STATE', 'PROJECTED_FINAL_IM_COST',
#        'START_YEAR', 'SUPPRESSION_METHOD', 'STR_DAMAGED_TOTAL',
#        'STR_DAMAGED_COMM_TOTAL', 'STR_DAMAGED_RES_TOTAL',
#        'STR_DESTROYED_TOTAL', 'STR_DESTROYED_COMM_TOTAL',
#        'STR_DESTROYED_RES_TOTAL', 'FATALITIES_RESPONDER', 'FATALITIES_PUBLIC',
#        'FINAL_REPORT_DATE', 'INCIDENT_ID_OLD', 'INC_MGMT_NUM_SITREPS',
#        'EVACUATION_REPORTED', 'PEAK_EVACUATIONS', 'STR_THREATENED_MAX',
# ...

# %%
dfi.loc[df.POO_STATE == "HI"][['INCIDENT_ID','FINAL_ACRES','STR_DESTROYED_TOTAL','STR_THREATENED_RES_MAX','INCIDENT_DESCRIPTION','POO_LATITUDE','POO_LONGITUDE','DISCOVERY_DATE','EXPECTED_CONTAINMENT_DATE']]
# Out:
#                                    INCIDENT_ID  FINAL_ACRES
# 3529                 2002_HI-HVP-0202_KUPUKUPU       3660.0  \
# 3530           2002_HI-HVP-0213_LEPO AHI (213)        150.0
# 4520              2003_HI-HVP-000301_PANAU IKI       2035.0
# 4521                     2003_HI-HVP-0361_LUHI       4930.0
# 5649           2004_HI-HVP-0412_KIPUKA PEPEIOA        656.0
# 6555             2005_FEMA 2573-FM-HI_LALAMILO      14200.0
# 6556      2005_FEMA 2574-FM-HI_AKONE-PULE HWY.       1128.0
# 6601          2005_HI-CNTY-2576-FM-HI_NANAKULI       2850.0
# 6602            2005_HI-CNTY-OA-05-005_WEIKELE        450.0
# 8278        2006_HI-CNTY-HA-06-0073_PUU MALI 2        320.0
# 8279           2006_HI-CNTY-MA-06-0002_MAALAEA       3973.0
# 8280         2006_HI-CNTY-MA-06-0003_UKUMEHAME        570.0
# 8581                 2006_MA-06-004_KAUPO FIRE       5000.0
# 11088            2007_HI-07-0018_WAIKOLOA FIRE       9139.0
# 11089             2007_HI-CNTY-07-0004_OLOWALU       2600.0
# ...

# %%
dfi.loc[df.POO_STATE == "HI"].to_csv('')
